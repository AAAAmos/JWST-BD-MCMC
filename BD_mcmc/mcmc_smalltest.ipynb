# %%
import numpy as np
import pandas as pd
import cupy as cp
import matplotlib.pyplot as plt
import glob
import astropy.units as u
import emcee
import corner
from scipy.interpolate import LinearNDInterpolator
from scipy.spatial import KDTree

# %% [markdown]
# ### results

# %%
results = pd.read_csv('mcmc_result.csv')

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6))

ax.errorbar(results['T_eff'], results['distance'], 
    xerr=[results['T_eff_loerr'], results['T_eff_uperr']],
    yerr=[results['distance_loerr'], results['distance_uperr']],
    ls='none', marker='o', c='grey', label='Mean of Posterior and 1$\sigma$'
    )
ax.scatter(results['T_peak'], results['distance_peak'], c='r', marker='*', s=70,
    zorder=10, label='Peak of Likelihood'
    )

# ax.set_xlim(1000, 1100)
# ax.set_yscale('log')
ax.set_xlabel('T$_{eff}$ (K)', fontsize=14)
ax.set_ylabel('Distance (pc)', fontsize=14)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.legend(loc='upper left', fontsize=14)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6))


# Plot the data
# ax.hist(results['T_eff'], bins=8, histtype='step', lw=2, color='k')
ax.scatter(results['type'], results['T_peak'], s=70, marker='*', c='r', label='Peak of Likelihood', zorder=10)

ax.errorbar(results['type'], results['T_eff'], 
    yerr=[results['T_eff_loerr'], results['T_eff_uperr']],
    xerr=[0],
    ls='none', marker='o', c='grey', label='Mean of Posterior and 1$\sigma$'
    )

ax.set_xlabel('Type', fontsize=14)
ax.set_xticks(range(10))
ax.set_xticklabels(['T0', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'Y0'])
ax.set_ylabel('T_eff', fontsize=14)
ax.tick_params(axis='both', which='major', labelsize=15)

ax.legend(fontsize=14)
ax.set_title('T_eff and Type from SED fitting', fontsize=14)

plt.show()

# %% [markdown]
# ### read results from CICA and plot

# %%
def plot_corner(N, model, plt_range, full=False):
    
    columns = ["Teff", "log_g", "[M/H]", "d"]
    data = pd.read_csv(f"./result2/BD{N}_mcmc_{model}.csv"
        , usecols=columns
    )
    
    if full:
        plot_ranges = None
    else:
        plot_ranges = plt_range
    
    figure = corner.corner(
        data,
        labels=[
            "Teff",
            "log(g)",
            "[M/H]",
            "d",
            r"$\Gamma \, [\mathrm{parsec}]$",
        ],
        quantiles=[0.16, 0.5, 0.84],
        show_titles=True,
        title_kwargs={"fontsize": 12},
        range=plot_ranges
    )
    
    title = f"BD{N}"+"\n"+"Peak beam"+"\n"
    for i in range(4):
        histo = np.histogram(data[columns[i]], bins=20, range=plt_range[i])
        max_index = np.argmax(histo[0])
        max_value = (histo[1][max_index]+histo[1][max_index+1])/2
        title+="    "+columns[i]+f": {max_value} \n"
        
    figure.suptitle(title, x=0.6, ha='left', fontsize=16)
    figure.savefig(f"./result2/BD{N}corner_5k.png")

# %%
plot_corner(
    '02',
    [(1100, 1300), (3.9, 5.5), (-0.6, 0.5), (1400, 2700)],
    # full=True
)

# %%
# find peak values

data = pd.read_csv(f"./results/BD23_mcmc.csv"
    , usecols=["Teff", "log_g", "[M/H]", "d"]
)

p1 = plt.hist(data["[M/H]"], bins=20, range=(0.3, 1.7))
# find max bin x-value
max_index = np.argmax(p1[0])
max_value = p1[1][max_index]
print(f"Teff peak: {max_value}")
# Out:
# Teff peak: 0.43999999999999995

# %%
N = '01'
columns = ["Teff", "log_g", "[M/H]", "d"]
data = pd.read_csv(f"./result2/BD{N}_mcmc_15k.csv"
    , usecols=columns
)
data['[M/H]'] = data['[M/H]']-1
data.to_csv(f"./result2/BD{N}_mcmc_15k.csv", index=False)

# %% [markdown]
# #### test

# %%
import os

os.environ["OMP_NUM_THREADS"] = "1"

import numpy as np
import pandas as pd
# import cupy as cp
import corner
import matplotlib.pyplot as plt
import emcee
from scipy.interpolate import LinearNDInterpolator
from scipy.spatial import KDTree
from multiprocessing import Pool

def interpolated_mag(theta, mag_table):
    Teff, log_g, Z, d = theta
    
    # Find the nearest point in the grid
    kdtree = KDTree(mag_table[['Teff', 'log_g', 'Z']])
    dist, points = kdtree.query(theta[:3], 1)
    
    mag = mag_table.iloc[points][['F115W', 'F150W', 'F277W', 'F444W']].values
    
    # Convert fluxes to magnitudes, mag_table is AB magnitude at 10 pc
    Mag = mag + 5 * np.log10(d / 10)
    
    return Mag

def log_likelihood(theta, mag_table, y, yerr):
    model_m = interpolated_mag(theta, mag_table)
    return -0.5 * np.sum(((np.array(y) - np.array(model_m)) / np.array(yerr)) ** 2)  # likelihood function

def log_prior(theta):
    Teff, log_g, Z, d = theta
    if 400 < Teff < 2400 a nd 2.9 < log_g < 5.6 and 0.4 < Z < 1.6 and 9 < d < 4000:  # set a reasonable range of parameters
        return 0.0
    return -np.inf

def log_probability(theta, mag_table, y, yerr):
    lp = log_prior(theta)
    if not np.isfinite(lp):  # if the parameter is not reasonable, return -inf (0 possibility)
        return -np.inf
    return lp + log_likelihood(theta, mag_table, y, yerr)

# file_dir = '/cluster/home/yuanchen/JWDT/BD_mcmc/'

mag_table = pd.read_feather('interpolated_ABmag.feather')
observation = pd.read_csv('/home/yuan/JWST/CentralDogma/4_Greed_/final.csv')

magnitudes = observation[['MAG_AUTO_F115W', 'MAG_AUTO_F150W', 'MAG_AUTO_F277W', 'MAG_AUTO_F444W']].values
magerr = observation[['MAGERR_AUTO_F115W', 'MAGERR_AUTO_F150W', 'MAGERR_AUTO_F277W', 'MAGERR_AUTO_F444W']].values
Mobs, Merr = lambda x: magnitudes[x-1], lambda x: magerr[x-1]

n = 2
theta = 1000, 4, 1, 1500
coefficients = np.array([500, 3, 1, 2000])

pos = theta + coefficients * np.random.randn(32, 4)
nwalkers, ndim = pos.shape

with Pool() as pool:
    sampler = emcee.EnsembleSampler(
        nwalkers, ndim, log_probability, pool=pool, args=(mag_table, Mobs(n), Merr(n))
    ) 
    sampler.run_mcmc(pos, 5000, progress=True)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# 100%|██████████| 5000/5000 [21:42<00:00,  3.84it/s]

# %%
# Remove the burn-in period
flat_samples = sampler.get_chain(discard=600, thin=10, flat=True)
print(flat_samples.shape, type(flat_samples))

# for i in range(ndim):
#     mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
#     q = np.diff(mcmc)
#     print(mcmc[1], q[0], q[1])
# Out:
# (14080, 4) <class 'numpy.ndarray'>

# %%
data = pd.DataFrame(flat_samples, columns=['Teff', 'log_g', '[M/H]', 'd'])
data.to_csv('./results/BD01_mcmc.csv')

# %%
plot_ranges = [(840, 1000), (3.2, 6), (0.3, 1.6), (400, 800)]

# fig = corner.corner(
#     flat_samples, labels=labels, range=plot_ranges
# )

figure = corner.corner(
    data,
    labels=[
        "Teff",
        "log(g)",
        "[M/H]",
        "d",
        r"$\Gamma \, [\mathrm{parsec}]$",
    ],
    quantiles=[0.16, 0.5, 0.84],
    show_titles=True,
    title_kwargs={"fontsize": 12},
    # range=plot_ranges
)
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
file_dir = '/cluster/home/yuanchen/JWST/BD_mcmc/'

n=5

if n<9:
    print(file_dir+f'results/BD_0{n}chain.png')
else:
    print(file_dir+f'results/BD_{n}chain.png')
# Out:
# /cluster/home/yuanchen/JWST/BD_mcmc/results/BD_05chain.png

# %% [markdown]
# ### functions

# %%
def interpolated_mag(theta, mag_table):
    
    ''' With the input parameters, find the nearest point in the grid and return the BD model magnitudes
    Returns:
    --------
    Mag: numpy array
        Magnitudes in F115W, F150W, F277W, F444W
        
    Parameters:
    -----------
    theta: numpy array
        Teff, log_g, Z, d
    mag_table: pandas DataFrame
        BD model magnitudes table
    ''' 
    
    Teff, log_g, Z, d = theta
    
    # Find the nearest point in the grid
    kdtree = KDTree(mag_table[['Teff','log_g','Z']])
    dist, points=kdtree.query(theta[:3],1)
    
    mag = mag_table.iloc[points][['F115W', 'F150W', 'F277W', 'F444W']].values
    
    # Convert fluxes to magnitudes, mag_table is AB magnitude at 10 pc
        # mag = log10(flux) * -2.5
        # log10(flux/d**2) = log10(flux) - 2*log10(d)
        # mag = -2.5*np.log10(flux) + 5*np.log10(d)
    Mag = mag + 5*np.log10(d/10)
    
    return Mag

def log_likelihood(theta, mag_table, y, yerr):
    Teff, log_g, Z, d = theta
    model_m = interpolated_mag(theta, mag_table)
    return -0.5 * np.sum(((np.array(y) - np.array(model_m))/ np.array(yerr)) ** 2 ) # likelihood function

def log_prior(theta):
    Teff, log_g, Z, d = theta
    if 400 < Teff < 2400 and 2.9 < log_g < 5.6 and 0.4 < Z < 1.6 and 9 < d < 3000: # set a reasonable range of parameters
        return 0.0
    return -np.inf

def log_probability(theta, mag_table, y, yerr):
    lp = log_prior(theta)
    if not np.isfinite(lp): # if the parameter is not reasonable, return -inf (0 possibility)
        return -np.inf
    return lp + log_likelihood(theta, mag_table, y, yerr) # set the probability as maximum likelihood

# %%
# use cupa, cant run on 230
def interpolated_mag(theta, mag_table):
    Teff, log_g, Z, d = theta
    
    # Find the nearest point in the grid
    kdtree = KDTree(mag_table[['Teff', 'log_g', 'Z']])
    dist, points = kdtree.query(theta[:3], 1)
    
    mag = mag_table.iloc[points][['F115W', 'F150W', 'F277W', 'F444W']].values
    
    # Convert fluxes to magnitudes, mag_table is AB magnitude at 10 pc
    Mag = mag + 5 * np.log10(d / 10)
    
    return Mag

def log_likelihood(theta, mag_table, y, yerr):
    model_m = interpolated_mag(theta, mag_table)
    return -0.5 * cp.sum(((cp.array(y) - cp.array(model_m)) / cp.array(yerr)) ** 2)  # likelihood function

def log_prior(theta):
    Teff, log_g, Z, d = theta
    if 400 < Teff < 2400 and 2.9 < log_g < 5.6 and 0.4 < Z < 1.6 and 9 < d < 3000:  # set a reasonable range of parameters
        return 0.0
    return -cp.inf

def log_probability(theta, mag_table, y, yerr):
    lp = log_prior(theta)
    if not cp.isfinite(lp):  # if the parameter is not reasonable, return -inf (0 possibility)
        return -cp.inf
    return lp + log_likelihood(theta, mag_table, y, yerr)

# %% [markdown]
# ### Run MCMC

# %%
mag_table = pd.read_feather('interpolated_ABmag.feather')
observation = pd.read_csv('../CentralDogma/4_Greed_/final.csv')

magnitudes = observation[['MAG_AUTO_F115W', 'MAG_AUTO_F150W', 'MAG_AUTO_F277W', 'MAG_AUTO_F444W']].values
magerr = observation[['MAGERR_AUTO_F115W', 'MAGERR_AUTO_F150W', 'MAGERR_AUTO_F277W', 'MAGERR_AUTO_F444W']].values
Mobs, Merr = lambda x: magnitudes[x-1], lambda x: magerr[x-1]

# %%
n = 1
theta = 1000, 4, 1, 1500
coefficients = np.array([500, 3, 1, 2000])

pos = theta + coefficients * np.random.randn(100, 4)
nwalkers, ndim = pos.shape

sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(mag_table, Mobs(n), Merr(n))
) 
sampler.run_mcmc(pos, 20000, progress=True)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 2/10000 [00:00<13:23, 12.45it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 4/10000 [00:00<14:52, 11.20it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 6/10000 [00:00<15:31, 10.72it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 8/10000 [00:00<15:46, 10.56it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 10/10000 [00:01<18:02,  9.23it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 11/10000 [00:01<22:32,  7.38it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 12/10000 [00:01<24:16,  6.86it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 13/10000 [00:01<28:03,  5.93it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 14/10000 [00:01<31:54,  5.22it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 15/10000 [00:02<34:01,  4.89it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 16/10000 [00:02<38:53,  4.28it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 17/10000 [00:02<36:23,  4.57it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 18/10000 [00:02<38:24,  4.33it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 19/10000 [00:03<37:25,  4.44it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 20/10000 [00:03<40:46,  4.08it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 21/10000 [00:03<39:17,  4.23it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 22/10000 [00:03<40:42,  4.08it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 23/10000 [00:04<38:55,  4.27it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 24/10000 [00:04<36:38,  4.54it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 25/10000 [00:04<38:39,  4.30it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 26/10000 [00:04<38:45,  4.29it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 27/10000 [00:05<37:50,  4.39it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 28/10000 [00:05<40:49,  4.07it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 29/10000 [00:05<42:52,  3.88it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 30/10000 [00:06<50:55,  3.26it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 31/10000 [00:06<49:02,  3.39it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 32/10000 [00:06<49:02,  3.39it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 33/10000 [00:06<43:42,  3.80it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 34/10000 [00:07<50:42,  3.28it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 35/10000 [00:07<50:05,  3.32it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 36/10000 [00:07<44:12,  3.76it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 37/10000 [00:07<48:20,  3.43it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 38/10000 [00:08<48:47,  3.40it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 39/10000 [00:08<54:30,  3.05it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 40/10000 [00:09<58:04,  2.86it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 41/10000 [00:09<56:08,  2.96it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 42/10000 [00:09<57:20,  2.89it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 43/10000 [00:10<56:50,  2.92it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 44/10000 [00:10<59:26,  2.79it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 45/10000 [00:10<59:31,  2.79it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 46/10000 [00:11<57:08,  2.90it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 47/10000 [00:11<59:10,  2.80it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 48/10000 [00:11<53:03,  3.13it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 49/10000 [00:12<55:03,  3.01it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|          | 50/10000 [00:12<59:23,  2.79it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   1%|          | 51/10000 [00:12<59:29,  2.79it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   1%|          | 52/10000 [00:13<1:00:46,  2.73it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   1%|          | 53/10000 [00:13<1:00:26,  2.74it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   1%|          | 54/10000 [00:14<1:00:12,  2.75it/s]/home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   1%|          | 55/10000 [00:14<58:43,  2.82it/s]  /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
#   1%|          |
#         412088515,  759264059, 1261368270, 2213458275,  283259385,
#        2726065315, 3680594417,  543776600, 3431943891, 4244779661,
#        3683169613, 2140132116, 2842277926, 2879063780, 4119388616,
#        4137222421, 2838201294, 2221088656, 1474955573, 3473082829,
#        4206139768,   24158174, 1269971206, 3283461141, 1954223426,
#        1631694782, 3745972094,  955500066, 1043739927, 1597697760,
#        3533429865,  427097739, 2940778004, 3293102577, 2754824578,
#        3745158066, 1816822481, 2634665447, 3927821121,  377128972,
#         187897436,  391877622,  630560924, 1890594641, 3793344696,
#        2534400303,  192846328, 3439335021, 1661201642,  179189008,
#        2158050242, 1640429639, 1110674537, 1725520605, 1464706828,
#         524797638,  994620975,  118457658, 1774408395, 2125486335,
#        2612312791, 3191486700,  144973217,  209367282, 2501392056,
#        2217975540,  859487283, 1929474887,  653602355,  582066954,
#         178190847,  991591651, 2483240523, 3677200482, 1903448877,
#         988015012, 1529732511, 1682941534, 2775638386, 3424781893,
#        3116592584, 3111257508, 3967737016, 3853080505, 2153490195,
#         906771726,   85473520,  229462290, 2861668990, 1285462819,
#        1552522738, 3428794971, 1126246187,  794345045, 2275777406,
#         491523491,   16423291,  744963816, 2462308711, 3521490184,
#        2254078952, 3863367871, 3574714744, 3302241327,  346492055,
#        3492822079, 2266212698,  742844066, 2951767685,  935529315,
#          26261352, 4113455826, 3267617757,  828835713], dtype=uint32), 195, 0, 0.0))

# %%
tau = sampler.get_autocorr_time()
print(tau)      
# This suggests that only about 40 steps are needed for the chain to “forget” where it started.
# 32 walkers, 5000 steps, 4 parameters, takes 1 hour to run in 140.114.94.230
# Out:
# [nan nan nan nan]
# /home/yuan/miniconda3/envs/Eva02/lib/python3.11/site-packages/emcee/autocorr.py:38: RuntimeWarning: invalid value encountered in divide
#   acf /= acf[0]

# %%
fig, axes = plt.subplots(4, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()       # get 32 values for each time (within 5000)
labels = ["Teff", "log_g", "Z", "d"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number")
# Out:
# Text(0.5, 0, 'step number')

# %%
import corner

# Let’s discard the initial 100 steps, thin by about half the autocorrelation time (15 steps), and flatten the chain so that we have a flat list of samples
flat_samples = sampler.get_chain(discard=8000, thin=2, flat=True)
print(flat_samples.shape)

plot_ranges = [(840, 1000), (3.2, 6), (0.3, 1.6), (400, 800)]

fig = corner.corner(
    flat_samples, labels=labels, range=plot_ranges
)
# Out:
# (32000, 4)
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
type(sampler)
# Out:
# emcee.ensemble.EnsembleSampler

# %%
theta=1300,1780,7,4500
print(theta[0])
print(type(theta))
pos = theta + 1e3*np.random.randn(32,4)  
print(type(pos))
# Out:
# 1300
# <class 'tuple'>
# <class 'numpy.ndarray'>

# %%
theta = 1100, 4.25, 1.0, 2178
interpolated_mag(theta, mag_table)
# Out:
# array([26.855605, 27.473055, 27.970555, 26.357405])

# %%
theta = 1000, 4.5, 0.6, 600
interpolated_mag(theta, mag_table)
# Out:
# array([24.61932187, 25.42002187, 26.23117187, 23.95257187])

# %%
mag_table
# Out:
#           Teff  log_g    Z      F115W      F150W      F277W      F444W  \
# 0        400.0    3.0  0.5  22.456816  23.941816  23.846566  17.565566
# 1        400.0    3.0  0.6  22.353566  23.971366  23.875616  17.571766
# 2        400.0    3.0  0.7  22.250316  24.000916  23.904666  17.577966
# 3        400.0    3.0  0.8  22.147066  24.030466  23.933716  17.584166
# 4        400.0    3.0  0.9  22.043816  24.060016  23.962766  17.590366
# ...        ...    ...  ...        ...        ...        ...        ...
# 114681  2400.0    5.5  1.1  12.723066  12.634866  13.400016  13.365116
# 114682  2400.0    5.5  1.2  12.697816  12.627166  13.372966  13.346166
# 114683  2400.0    5.5  1.3  12.672566  12.619466  13.345916  13.327216
# 114684  2400.0    5.5  1.4  12.647316  12.611766  13.318866  13.308266
# 114685  2400.0    5.5  1.5  12.622066  12.604066  13.291816  13.289316
#
#            mass   R/Rsun
# 0         0.670  0.13250
# 1         0.676  0.13308
# 2         0.682  0.13366
# 3         0.688  0.13424
# 4         0.694  0.13482
# ...         ...      ...
# 114681  100.442  0.09114
# 114682  102.314  0.09198
# 114683  104.186  0.09282
# 114684  106.058  0.09366
# 114685  107.930  0.09450
#
# [114686 rows x 9 columns]

# %%
### interpolate templates

# %% [markdown]
# ### interpolate

# %%
# SB
ABmag_table = pd.read_csv('ABmag_table.csv')

Teff_new_grid = np.linspace(400, 2000, 320+1)
log_g_new_grid = np.linspace(3, 5.5, 25+1)
Z_new_grid = np.linspace(-0.5, 0.5, 10+1)

# ATMO
# AT_mag_table = pd.read_csv('ATMO_mag_table.csv')

# Teff_new_grid = np.linspace(400, 1200, 160+1)
# log_g_new_grid = np.linspace(2.5, 5.5, 30+1)
# Z_new_grid = np.linspace(-1.0, 0.3, 13+1)

# LOWZ
# LZ_mag_table = pd.read_csv('LOWZ_mag_table.csv')

# Teff_new_grid = np.linspace(500, 1600, 220+1)
# log_g_new_grid = np.linspace(3.5, 5.25, 17+1)
# Z_new_grid = np.linspace(-2.5, 1.0, 35+1)
# # CtoO_new_grid = np.linspace(0.1, 0.85, 15+1)
# # logKzz_new_grid = np.linspace(-1.0, 10.0, 11+1)
# # CtoO_new_grid = np.array([0.1, 0.55, 0.85])
# # logKzz_new_grid = np.array([-1.0, 2.0, 10.0])
# CtoO_new_grid = np.array([0.55])
# logKzz_new_grid = np.array([2.0])

# %% [markdown]
# #### 3D lets go

# %%
data = ABmag_table

# Create a meshgrid for Teff, log_g, and Z
X, Y, Z = np.meshgrid(Teff_new_grid, log_g_new_grid, Z_new_grid, indexing='ij')
# Tep, G, Z, C, K = np.meshgrid(Teff_new_grid, log_g_new_grid, Z_new_grid, CtoO_new_grid, logKzz_new_grid, indexing='ij')

# Combine Teff, log(g), and Z into a single array of points for interpolation
points = data[['Teff', 'log_g', '[M/H]']].values
# points = data[['Teff', 'logg', 'logZ', 'CtoO', 'logKzz']].values
values = data[['F115W', 'F150W', 'F277W', 'F444W']].values

# Perform the 3D interpolation
interp = LinearNDInterpolator(points, values)

# Create the grid of points where we want to interpolate
grid_points = np.array([X.flatten(), Y.flatten(), Z.flatten()]).T
# grid_points = np.array([Tep.flatten(), G.flatten(), Z.flatten(), C.flatten(), K.flatten()]).T

# Interpolate the data
interpolated_values = interp(grid_points)

# Check for NaNs in the interpolated data
if np.any(np.isnan(interpolated_values)):
    print("Interpolation resulted in NaNs. Adjust grid or data.")
else:
    # Reshape the interpolated values to the shape of the grid
    interpolated_values = interpolated_values.reshape(len(Teff_new_grid), len(log_g_new_grid), len(Z_new_grid), -1)
    # interpolated_values = interpolated_values.reshape(
        # len(Teff_new_grid), len(log_g_new_grid), len(Z_new_grid), len(CtoO_new_grid), len(logKzz_new_grid),
        # -1)
    
    # Flatten the grids and interpolated data
    Teff_flat = X.flatten()
    log_g_flat = Y.flatten()
    Z_flat = Z.flatten()
    # Teff_flat = Tep.flatten()
    # log_g_flat = G.flatten()
    # Z_flat = Z.flatten()
    # C_flat = C.flatten()
    # K_flat = K.flatten()
    F115W_flat = interpolated_values[..., 0].flatten()
    F150W_flat = interpolated_values[..., 1].flatten()
    F277W_flat = interpolated_values[..., 2].flatten()
    F444W_flat = interpolated_values[..., 3].flatten()
    
    # Create a DataFrame with the flattened data
    data = {
        'Teff': Teff_flat,
        'log_g': log_g_flat,
        '[M/H]': Z_flat,
        # 'CtoO': C_flat,
        # 'logKzz': K_flat,
        'F115W': F115W_flat,
        'F150W': F150W_flat,
        'F277W': F277W_flat,
        'F444W': F444W_flat
    }
    
    df = pd.DataFrame(data)
    
    # Save the DataFrame to a Feather file
    df.to_feather('interpolated_SB_mag.feather')
    
    print("Interpolation and saving completed successfully.")
# Out:
# Interpolation and saving completed successfully.

# %%
mag_tabel = pd.read_feather('interpolated_SB_mag.feather')
len(mag_tabel)
# Out:
# 91806

# %%
221*18*36*9
# Out:
# 1288872

# %% [markdown]
# #### 2D test

# %%
X, Y = np.meshgrid(Teff_new_grid, log_g_new_grid)

# ABmag_table_zslice = ABmag_table[ABmag_table['Z'] == 0.5]
interp = LinearNDInterpolator(ABmag_table[['Teff', 'log(g)']].values, 
                            ABmag_table[['F115W', 'F150W', 'F277W', 'F444W']].values)
Z = interp(X, Y)

Teff_flat = X.flatten()
log_g_flat = Y.flatten()
Z_flat = Z.reshape(-1, 4)

# Create a DataFrame with the flattened data
data = {
    'Teff': Teff_flat,
    'log_g': log_g_flat,
    'F115W': Z_flat[:, 0],
    'F150W': Z_flat[:, 1],
    'F277W': Z_flat[:, 2],
    'F444W': Z_flat[:, 3]
}

df = pd.DataFrame(data)

# Save the DataFrame to a Feather file
# df.to_feather(f'interpolated_ABmag.feather')
# Out:
# [[[21.83756562 24.19081562 24.08531562 17.63156562]
#   [21.69886562 23.99546562 23.93321562 17.56606562]
#   [21.56016562 23.80011562 23.78111562 17.50056562]
#   ...
#   [ 9.97869062  9.99676562 10.36434062 10.44601562]
#   [ 9.96037812  9.97679062 10.34445312 10.43041562]
#   [ 9.94206562  9.95681562 10.32456562 10.41481562]]
#
#  [[21.88609503 24.13356072 24.10541366 17.65999699]
#   [21.74739503 23.93821072 23.95331366 17.59449699]
#   [21.60869503 23.74286072 23.80121366 17.52899699]
#   ...
#   [10.08444382 10.10368976 10.47979339 10.55893129]
#   [10.08766648 10.10564485 10.4851697  10.56638326]
#   [10.09088915 10.10759994 10.49054601 10.57383523]]
#
#  [[21.93462445 24.07630582 24.1255117  17.68842837]
#   [21.79592445 23.88095582 23.9734117  17.62292837]
#   [21.7295215  23.69242543 23.81329405 17.55811954]
#   ...
#   [10.23326735 10.25447407 10.64577378 10.7179509 ]
#   [10.23649001 10.25642916 10.65115009 10.72540287]
#   [10.23971268 10.25838425 10.65652641 10.73285484]]
#
#  ...
#
#  [[23.22696562 23.84571562 25.16471562 18.53791562]
#   [23.32841562 23.77316562 24.94771562 18.47616562]
#   [23.42986562 23.70061562 24.73071562 18.41441562]
#   ...
#   [12.60301017 12.44998868 13.24546261 13.21556694]
#   [12.56944668 12.42215527 13.22452017 13.19302623]
#   [12.53541562 12.39406562 13.20331562 13.17016562]]
#
#  [[23.94626562 24.04401562 24.98301562 18.59711562]
#   [24.04771562 23.97146562 24.76601562 18.53536562]
#   [24.14916562 23.89891562 24.54901562 18.47361562]
#   ...
#   [12.7158504  12.55957715 13.37116412 13.33665378]
#   [12.7129129  12.54852715 13.36738912 13.33506628]
#   [12.67911562 12.52056562 13.34631562 13.31236562]]
#
#  [[24.66556562 24.24231562 24.80131562 18.65631562]
#   [24.49936562 24.11946562 24.69701562 18.60576562]
#   [24.33316562 23.99661562 24.59271562 18.55521562]
#   ...
#   [12.82869062 12.66916562 13.49686562 13.45774062]
#   [12.82575312 12.65811562 13.49309062 13.45615312]
#   [12.82281562 12.64706562 13.48931562 13.45456562]]]

# %% [markdown]
# #### troble shooting

# %%
print(ABmag_table[['Teff', 'log(g)']].describe())
print(f'Teff_new_grid range: {Teff_new_grid.min()} to {Teff_new_grid.max()}')
print(f'log_g_new_grid range: {log_g_new_grid.min()} to {log_g_new_grid.max()}')
# Out:
#               Teff       log(g)
# count  1131.000000  1131.000000
# mean    971.799293     4.216414
# std     657.485384     0.810721
# min     200.000000     3.000000
# 25%     425.000000     3.505000
# 50%     750.000000     4.250000
# 75%    1500.000000     5.000000
# max    2401.000000     5.500000
# Teff_new_grid range: 400.0 to 2400.0
# log_g_new_grid range: 1000.0 to 316227.7660168379

# %%
print(f'Number of NaNs in interpolated Z: {np.isnan(Z).sum()}')
# Out:
# Number of NaNs in interpolated Z: 41704

# %%
plt.scatter(ABmag_table['Teff'], ABmag_table['log(g)'], label='Data Points')
plt.scatter(X.flatten(), Y.flatten(), label='Interpolation Grid', alpha=0.1)
plt.xlabel('Teff')
plt.ylabel('log(g)')
plt.legend()
plt.show()

# %%
# read feather file
ABmag_table = pd.read_feather('interpolated_ABmag_0.5Z.feather')

# %%
ABmag_table
# Out:
#               Teff          log_g  F115W  F150W  F277W  F444W
# 0       400.000000    1000.000000    NaN    NaN    NaN    NaN
# 1       404.545455    1000.000000    NaN    NaN    NaN    NaN
# 2       409.090909    1000.000000    NaN    NaN    NaN    NaN
# 3       413.636364    1000.000000    NaN    NaN    NaN    NaN
# 4       418.181818    1000.000000    NaN    NaN    NaN    NaN
# ...            ...            ...    ...    ...    ...    ...
# 11461  2381.818182  316227.766017    NaN    NaN    NaN    NaN
# 11462  2386.363636  316227.766017    NaN    NaN    NaN    NaN
# 11463  2390.909091  316227.766017    NaN    NaN    NaN    NaN
# 11464  2395.454545  316227.766017    NaN    NaN    NaN    NaN
# 11465  2400.000000  316227.766017    NaN    NaN    NaN    NaN
#
# [11466 rows x 6 columns]

# %% [markdown]
# #### interpolate test

# %%
subset = ABmag_table[:78]

# %%
Teff_grid = np.linspace(200, 2400, 44+1)
log_g_grid = np.linspace(3, 3.255, 50)

X, Y = np.meshgrid(Teff_grid, log_g_grid)
interp = LinearNDInterpolator(subset[['Teff', 'log(g)']].values, 
                            subset[['F115W', 'F150W', 'F277W', 'F444W']].values)
Z = interp(X, Y)

# %%
Teff_flat = X.flatten()
log_g_flat = Y.flatten()
Z_flat = Z.reshape(-1, 4)

# %%
Teff_flat
# Out:
# array([ 200.,  250.,  300., ..., 2300., 2350., 2400.])

# %%
Z_flat[:, 0]
# Out:
# array([35.33556562, 30.81606562, 27.40056562, ..., 10.66006562,
#        10.49081562, 10.32156562])

# %%
Z_flat
# Out:
# array([[35.33556562, 33.46381562, 32.66306562, 21.31131562],
#        [30.81606562, 30.20406562, 29.60506562, 20.02281562],
#        [27.40056562, 27.76656562, 27.23981562, 19.02931562],
#        ...,
#        [10.66006562, 10.71281562, 11.11956562, 11.10881562],
#        [10.49081562, 10.52706562, 10.93369062, 10.96456562],
#        [10.32156562, 10.34131562, 10.74781562, 10.82031562]])

# %%
Z
# Out:
# array([[[35.33556562, 33.46381562, 32.66306562, 21.31131562],
#         [30.81606562, 30.20406562, 29.60506562, 20.02281562],
#         [27.40056562, 27.76656562, 27.23981562, 19.02931562],
#         ...,
#         [10.30831562, 10.35631562, 10.72231562, 10.72681562],
#         [10.12519062, 10.15656562, 10.52344062, 10.57081562],
#         [ 9.94206562,  9.95681562, 10.32456562, 10.41481562]],
#
#        [[35.33410134, 33.45691766, 32.66334623, 21.31256562],
#         [30.81481052, 30.19794828, 29.60636664, 20.02430032],
#         [27.40006562, 27.76137174, 27.24167787, 19.03093807],
#         ...,
#         [10.31549419, 10.36359113, 10.73042277, 10.73461154],
#         [10.13293552, 10.16441256, 10.53207838, 10.57909113],
#         [ 9.94981052,  9.96466256, 10.33320338, 10.42309113]],
#
#        [[35.33263705, 33.4500197 , 32.66362685, 21.31381562],
#         [30.81355542, 30.19183093, 29.60766766, 20.02578501],
#         [27.39956562, 27.75617787, 27.24354011, 19.03256052],
#         ...,
#         [10.32267277, 10.37086664, 10.73852991, 10.74240746],
#         [10.14068042, 10.1722595 , 10.54071613, 10.58736664],
#         [ 9.95755542,  9.9725095 , 10.34184113, 10.43136664]],
#
#        ...,
#
#        [[35.26674419, 33.13961154, 32.6762544 , 21.37006562],
#         [30.75707583, 29.91655032, 29.66621358, 20.09259623],
#         [27.37706562, 27.52245338, 27.32734113, 19.10557072],
#         ...,
#         [10.64570848, 10.6982646 , 11.10335134, 11.09322379],
#         [10.47645848, 10.5125146 , 10.91747634, 10.94897379],
#         [10.30607583, 10.32562174, 10.73054011, 10.8037646 ]],
#
#        [[35.26527991, 33.13271358, 32.67653501, 21.37131562],
#         [30.75582072, 29.91043297, 29.6675146 , 20.09408093],
#         [27.37656562, 27.5172595 , 27.32920338, 19.10719317],
#         ...,
#         [10.65288705, 10.70554011, 11.11145848, 11.1010197 ],
#         [10.48363705, 10.51979011, 10.92558348, 10.9567697 ],
#         [10.31382072, 10.33346868, 10.73917787, 10.81204011]],
#
#        [[35.26381562, 33.12581562, 32.67681562, 21.37256562],
#         [30.75456562, 29.90431562, 29.66881562, 20.09556562],
#         [27.37606562, 27.51206562, 27.33106562, 19.10881562],
#         ...,
#         [10.66006562, 10.71281562, 11.11956562, 11.10881562],
#         [10.49081562, 10.52706562, 10.93369062, 10.96456562],
#         [10.32156562, 10.34131562, 10.74781562, 10.82031562]]])

# %%
plt.plot(Teff_grid, Z[0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fc9a5f6e810>,
#  <matplotlib.lines.Line2D at 0x7fc9a5eb4990>,
#  <matplotlib.lines.Line2D at 0x7fc9a60bb850>,
#  <matplotlib.lines.Line2D at 0x7fc9a5f432d0>]

# %%
plt.plot(log_g_grid, Z[:, 0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fc9a5696250>,
#  <matplotlib.lines.Line2D at 0x7fc9a5bad490>,
#  <matplotlib.lines.Line2D at 0x7fc9a5bad1d0>,
#  <matplotlib.lines.Line2D at 0x7fc9a5badd90>]

# %%
plt.pcolormesh(X, Y, Z/40)
plt.plot(subset['Teff'].values, subset['log(g)'].values, "ok", label="input point")
plt.legend()
plt.colorbar()
# plt.axis("equal")
plt.show()

# %%
from scipy.interpolate import LinearNDInterpolator
import numpy as np
import matplotlib.pyplot as plt
rng = np.random.default_rng()
x = rng.random(10) - 0.5
y = rng.random(10) - 0.5
z = np.hypot(x, y)
X = np.linspace(min(x), max(x))
Y = np.linspace(min(y), max(y))
X, Y = np.meshgrid(X, Y)  # 2D grid for interpolation
interp = LinearNDInterpolator(list(zip(x, y)), z)
Z = interp(X, Y)
plt.pcolormesh(X, Y, Z, shading='auto')
plt.plot(x, y, "ok", label="input point")
plt.legend()
plt.colorbar()
plt.axis("equal")
plt.show()

# %%
Z.shape
# Out:
# (50, 50)

# %%
for i in range(len(Z_grid)):

# %% [markdown]
# ## Magnitude csv table

# %%
from mcmc4bd import read_flux_table

dir1 = '/home/yuan/LePhare/lephare_dev/sed/STAR/'
flux_tables = glob.glob(dir1+'Sonora_Bobcat/flux_table/*')
colums = ['Teff', 'log(g)', 'mass', 'R/Rsun', 'F115W', 'F150W', 'F277W', 'F444W']

ABmag = lambda flux: -2.5*(flux-np.log10(3631000)) # convert flux to magnitude, flux unit: log(mJy)
flux_table = read_flux_table(flux_tables[0])[colums]
flux_table[['F115W', 'F150W', 'F277W', 'F444W']] = flux_table[['F115W', 'F150W', 'F277W', 'F444W']].apply(ABmag)
flux_tablep = read_flux_table(flux_tables[1])[colums]
flux_tablep[['F115W', 'F150W', 'F277W', 'F444W']] = flux_tablep[['F115W', 'F150W', 'F277W', 'F444W']].apply(ABmag)
flux_tablem = read_flux_table(flux_tables[2])[colums]
flux_tablem[['F115W', 'F150W', 'F277W', 'F444W']] = flux_tablem[['F115W', 'F150W', 'F277W', 'F444W']].apply(ABmag)

flux_table['Z'] = 1.0
flux_tablep['Z'] = 1.5
flux_tablem['Z'] = 0.5

m1 = flux_tablem.merge(flux_table, how='outer')
m2 = m1.merge(flux_tablep, how='outer')
m2.to_csv('ABmag_table.csv', index=False)
